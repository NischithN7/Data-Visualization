# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame

# %%
#1)Which region has max oil reserves from 2014 to 2016?
df = pd.read_csv("oil_reserves.csv")
df["max"]=(df["2014"] + df["2015"] + df["2016"])
print("Region with maximum oil reserves from 2014 to 2016:")
#print(df.sort_values('max',ascending=False)["Country/ Region"].head())
print(df.sort_values('max',ascending=False)["Country/ Region"].iloc[0])
# Out:
# Region with maximum oil reserves from 2014 to 2016:
# Venezuela

# %%
#2)With suitable visualization show the oil reserves of India from 2010 to 2016.
india = df.iloc[48:49,1:9]
print(india)
labels = ['2010', '2011', '2012', '2013','2014','2015','2016']
sizes = [5.833, 5.704, 5.72, 5.711, 5.743, 4.786, 4.677]

explode = (0, 0, 0, 0, 0, 0, 0)  

plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  
plt.title('India')
plt.show()
# Out:
#    Country/ Region   2010   2011  2012   2013   2014   2015   2016
# 48           India  5.833  5.704  5.72  5.711  5.743  4.786  4.677

# %%
#3)List the countries having maximum oil reserves in each region.

# %%
#5)Find the world’s top 5 countries having maximum oil reserves in the 2015.
#Show their % of share in total oil reserve for the same year.
print("World’s top 5 countries having maximum oil reserves in the 2015:")
print(df.sort_values('2015',ascending=False)["Country/ Region"].head())

a = df.sort_values('2015',ascending=False)["Country/ Region"].head()
b = df.sort_values('2015',ascending=False)["2015"].head()
explode = (0, 0, 0, 0, 0)  
plt.pie(b, explode=explode, labels=a, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  
plt.title('percentage of share of oil in 2015')
plt.show()
# Out:
# World’s top 5 countries having maximum oil reserves in the 2015:
# 9        Venezuela
# 27    Saudi Arabia
# 1           Canada
# 22            Iran
# 23            Iraq
# Name: Country/ Region, dtype: object

# %%
#1)Which state has produced max milk in year 2013-14?
ds = pd.read_csv("milk_production.csv")
ds["max3"]=(ds["Cow Milk-2013-14"] + ds["Boffalo Milk-2013-14"] + ds["Goat Milk-2013-14"])
ds.sort_values('max3',ascending=False)["State/ UT Name"].iloc[0]
# Out:
# 'Uttar Pradesh'

# %%
#2)List top 5 milk producing states in each year from 2010 to 2015
print("In 2010:")
ds["max4"]=(ds["Cow Milk-2010-11"] + ds["Boffalo Milk-2010-11"] + ds["Goat Milk-2010-11"])
print(ds.sort_values('max4',ascending=False)["State/ UT Name"].head())
print("In 2011:")
ds["max5"]=(ds["Cow Milk-2011-12"] + ds["Boffalo Milk-2011-12"] + ds["Goat Milk-2011-12"])
print(ds.sort_values('max5',ascending=False)["State/ UT Name"].head())
print("In 2013:")
ds["max6"]=(ds["Cow Milk-2013-14"] + ds["Boffalo Milk-2013-14"] + ds["Goat Milk-2013-14"])
print(ds.sort_values('max6',ascending=False)["State/ UT Name"].head())
print("In 2014:")
ds["max7"]=(ds["Cow Milk-2014-15"] + ds["Boffalo Milk-2014-15"] + ds["Goat Milk-2014-15"])
print(ds.sort_values('max7',ascending=False)["State/ UT Name"].head())
print("In 2015:")
ds["max8"]=(ds["Cow Milk-2015-16"] + ds["Boffalo Milk-2015-16"] + ds["Goat Milk-2015-16"])
print(ds.sort_values('max8',ascending=False)["State/ UT Name"].head())
# Out:
# In 2010:
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 6            Gujarat
# Name: State/ UT Name, dtype: object
# In 2011:
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 14       Maharashtra
# Name: State/ UT Name, dtype: object
# In 2013:
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 6            Gujarat
# 20            Punjab
# Name: State/ UT Name, dtype: object
# In 2014:
# 26     Uttar Pradesh
# 21         Rajasthan
# 6            Gujarat
# 13    Madhya Pradesh
# 20            Punjab
# Name: State/ UT Name, dtype: object
# In 2015:
# 26     Uttar Pradesh
# 21         Rajasthan
# 6            Gujarat
# 13    Madhya Pradesh
# 0     Andhra Pradesh
# Name: State/ UT Name, dtype: object

# %%
#3)Calculate average milk production by cow, buffalo and goat in each year for selected state.

# %%
#Draw line graph showing total milk production for last 5 years of selected state
