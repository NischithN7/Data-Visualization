# %%
import pandas as pd
df = pd.read_csv("milk_production.csv")
print(df.head())
ex=df[["State/ UT Name","Cow Milk-2010-11"]]
print(ex)
# Out:
#   Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 0    State     Andhra Pradesh            3102.0            3377.0
# 1    State  Arunachal Pradesh              28.0              22.0
# 2    State              Assam             666.0             658.0
# 3    State              Bihar            3561.0            3661.0
# 4    State       Chhattisgarh             644.0             701.0
#
#    Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  Boffalo Milk-2010-11  \
# 0            3799.0              3079              3369                8101.0
# 1              43.0                46                50                   NaN
# 2             677.0               685               703                 101.0
# 3            3986.0              4318              4881                2798.0
# 4             788.0               824               919                 343.0
#
#    Boffalo Milk-2011-12  Boffalo Milk-2013-14  Boffalo Milk-2014-15  \
# ...

# %%
#1.	Which state has produced max milk in year 2013-14?
df["milk"] = df["Cow Milk-2013-14"] + df["Boffalo Milk-2013-14"] + df["Goat Milk-2013-14"]
print(df["milk"].max())

df[df["milk"]==df["milk"].max()]["State/ UT Name"]
# Out:
# 24195.0
# 26    Uttar Pradesh
# Name: State/ UT Name, dtype: object

# %%
#2.list top 5 milk producing states in each year from 2010 to 2015
df["y2011"] =(df["Cow Milk-2010-11"] + df["Boffalo Milk-2010-11"] + df["Goat Milk-2010-11"])
print("Year 2011")
print(df.sort_values('y2011',ascending=False)["State/ UT Name"].head())

df["y2012"]= df["Cow Milk-2011-12"] + df["Boffalo Milk-2011-12"] + df["Goat Milk-2011-12"]
print("Year 2012")
print(df.sort_values('y2012',ascending=False)["State/ UT Name"].head())

df["y2014"]= df["Cow Milk-2013-14"] + df["Boffalo Milk-2013-14"] + df["Goat Milk-2013-14"]
print("Year 2014")
print(df.sort_values('y2014',ascending=False)["State/ UT Name"].head())

df["y2015"]= df["Cow Milk-2014-15"] + df["Boffalo Milk-2014-15"] + df["Goat Milk-2014-15"]
print("Year 2015")
print(df.sort_values('y2015',ascending=False)["State/ UT Name"].head())
# Out:
# Year 2011
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 6            Gujarat
# Name: State/ UT Name, dtype: object
# Year 2012
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 14       Maharashtra
# Name: State/ UT Name, dtype: object
# Year 2014
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 6            Gujarat
# 20            Punjab
# Name: State/ UT Name, dtype: object
# Year 2015
# 26     Uttar Pradesh
# 21         Rajasthan
# 6            Gujarat
# 13    Madhya Pradesh
# 20            Punjab
# Name: State/ UT Name, dtype: object

# %%
#3 calculate average milk production by cow in each year for selected state
#df["cow_allyear"]=df["Cow Milk-2010-11"]+df["Cow Milk-2011-12"]+df["Cow Milk-2013-14"]+df["Cow Milk-2014-15"]+df["Cow Milk-2015-16"]
df[df["Cow Milk-2010-11"]==df["Cow Milk-2010-11"].mean()["State/ UT Name"]=="Uttar Pradesh"]
#df[df["cow_allyear"].mean() and df["State/ UT Name"]=="Uttar Pradesh"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fd3697d92650> in <module>
#       1 #3 calculate average milk production by cow in each year for selected state
#       2 #df["cow_allyear"]=df["Cow Milk-2010-11"]+df["Cow Milk-2011-12"]+df["Cow Milk-2013-14"]+df["Cow Milk-2014-15"]+df["Cow Milk-2015-16"]
# ----> 3 df[df["Cow Milk-2010-11"]==df["Cow Milk-2010-11"].mean()["State/ UT Name"]=="Uttar Pradesh"]
#       4 #df[df["cow_allyear"].mean() and df["State/ UT Name"]=="Uttar Pradesh"]
#
# TypeError: 'float' object is not subscriptable

# %%
pro = pd.read_csv("products.csv")
pro
# Out:
#        Year              Product line  Product type              Product  \
# 0      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 1      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 2      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 3      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 4      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 5      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 6      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 7      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 8      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 9      2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 10     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# 11     2004         Camping Equipment  Cooking Gear  TrailChef Water Bag
# ...

# %%
pro["Product"].unique()
# Out:
# array(['TrailChef Water Bag', 'TrailChef Canteen',
#        'TrailChef Kitchen Kit', 'TrailChef Cup', 'TrailChef Cook Set',
#        'TrailChef Deluxe Cook Set', 'TrailChef Single Flame',
#        'TrailChef Double Flame', 'TrailChef Kettle', 'TrailChef Utensils',
#        'Star Lite', 'Star Dome', 'Star Gazer 2', 'Star Gazer 3',
#        'Star Gazer 6', 'Star Peg', 'Hibernator Lite', 'Hibernator',
#        'Hibernator Extreme', 'Hibernator Self - Inflating Mat',
#        'Hibernator Pad', 'Hibernator Pillow', 'Hibernator Camp Cot',
#        'Canyon Mule Climber Backpack', 'Canyon Mule Weekender Backpack',
#        'Canyon Mule Journey Backpack', 'Canyon Mule Extreme Backpack',
#        'Canyon Mule Cooler', 'Canyon Mule Carryall', 'Firefly Lite',
#        'Firefly Mapreader', 'Firefly 2', 'Firefly 4', 'Firefly Extreme',
#        'Firefly Multi-light', 'EverGlow Single', 'EverGlow Double',
#        'EverGlow Kerosene', 'EverGlow Butane', 'EverGlow Lamp',
# ...

# %%
pro["Retailer country"].unique()
# Out:
# array(['United States', 'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea',
#        'China', 'Singapore', 'Australia', 'Netherlands', 'Sweden',
#        'Finland', 'Denmark', 'France', 'Germany', 'United Kingdom',
#        'Belgium', 'Switzerland', 'Austria', 'Italy', 'Spain'],
#       dtype=object)
